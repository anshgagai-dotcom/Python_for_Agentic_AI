# %% [markdown]
# WEEK 0 — Setup & First Run

# %% [markdown]
# CLASS 1 — What is Programming & Where We Are Going

# %% [markdown]
# 1) 5 lines mein (English ya Hindi), brush karne ka step-by-step "program" likho. (Yeh aapke brain ko steps mein sochna sikhata hai.)

# %% [markdown]
# 1. Brush uthao.
# 2. Usme toothpaste lagao.
# 3. Upar ke teeth 1 minute brush karo.
# 4. Neeche ke teeth 1 minute brush karo.
# 5. Paani se mooh saaf karo.

# %% [markdown]
# 1. Pick up your toothbrush.
# 2. Put toothpaste on the toothbrush.
# 3. Brush all your teeth gently for 2 minutes.
# 4. Rinse your mouth and toothbrush with water.
# 5. Put the toothbrush back in its place.

# %% [markdown]
# 1. Toothbrush uthao.
# 2. Toothpaste toothbrush par lagao.
# 3. 2 minute tak saare daant achhe se brush karo.
# 4. Paani se munh aur toothbrush dho lo.
# 5. Toothbrush ko uski jagah par rakh do.

# %% [markdown]
# 2) 3 sentences likho: "Main AI engineer kyun banna chahta/chahti hoon?

# %% [markdown]
# I want to become an AI Engineer because I enjoy solving real-world problems using technology.
# I am passionate about Python, Data Analytics, and Generative AI, and I want to build intelligent applications.
# My goal is to create innovative AI solutions that make people's lives easier and have a positive impact on society.

# %% [markdown]
# 1. Main AI Engineer banna chahta hoon kyunki mujhe technology ki help se real-life problems solve karna pasand hai.
# 2. Mujhe Python, Data Analytics aur Generative AI mein bahut interest hai, aur main smart AI applications banana chahta hoon.
# 3. Mera goal hai aise AI solutions develop karna jo logon ka kaam aasan banaye aur society par positive impact dale.

# %% [markdown]
# Week-01

# %% [markdown]
#  Class 11 Variables: The Computer's Memory Boxes

# %% [markdown]
# 1)Inhe achhe naam wale variables mein store karke print karo: apna name, age, city, favourite subject, dream job.

# %% [markdown]
# student_name = "Priya"
# student_age = 17
# student_city = "Delhi"
# favourite_subject = "Computer Science"
# dream_job = "AI Engineer"
#
# print(student_name)
# print(student_age)
# print(student_city)
# print(favourite_subject)
# print(dream_job)

# %%
student_name = "Priya"
student_age = 17
student_city = "Delhi"
favourite_subject = "Computer Science"
dream_job = "AI Engineer"
print(student_name)
print(student_age)
print(student_city)
print(favourite_subject)
print(dream_job)
# Out:
# Priya
# 17
# Delhi
# Computer Science
# AI Engineer

# %% [markdown]
# Class 12 Numbers & Arithmetic

# %% [markdown]
# Addition (+)
# Subtraction (-)
# Multiplication (*)
# Division (/)
# Floor Division (//)
# Modulus (%)
# Exponent, Power (**)
# BODMAS

# %% [markdown]
#  1)Radius 7 wale circle ka area nikalo (use 3.14159 * 7 ** 2).

# %% [markdown]
# #Example 1
# radius = 7
# area = 3.14159 * radius ** 2
# print(area)

# %%
#1
radius = 7
area = 3.14159 * radius ** 2
print(area)
# Out:
# 153.93791

# %% [markdown]
#   2)Ek student ne 500 mein se 425 marks paaye. Percentage print karo.

# %% [markdown]
# #1
# Total_Marks = 500
# Obtain_Marks = 425
# Percentage = (Obtain_Marks / Total_Marks) * 100
# print(Percentage)

# %%
#1
Total_Marks = 500
Obtain_Marks = 425
Percentage = (Obtain_Marks / Total_Marks) * 100
print(Percentage)
# Out:
# 85.0

# %% [markdown]
# #Example 2
# Total_Marks = 700
# Scored_Marks = 639
# Percentage = (Scored_Marks / Total_Marks) * 100
# print ("Percentage=", Percentage, "%")

# %%
#Example 2
Total_Marks = 700
Scored_Marks = 639
Percentage = (Scored_Marks / Total_Marks) * 100
print ("Percentage=", Percentage, "%")
# Out:
# Percentage= 91.28571428571428 %

# %% [markdown]
# #Example3
# Maximum_Score = 250
# Employee_Score = 225
# Performance = (Employee_Score / Maximum_Score) * 100
# print ("Performance=", Performance, "%")

# %%
#Example3
Maximum_Score = 250
Employee_Score = 225
Performance = (Employee_Score / Maximum_Score) * 100
print ("Performance=", Performance, "%")
# Out:
# Performance= 90.0 %

# %% [markdown]
# #Example4
# Target_Runs = 300
# Run_Scored = 255
# Achievement = (Run_Scored / Target_Runs) * 100
# print ("Achievement=", Achievement, "%")

# %%
#Example4
Target_Runs = 300
Run_Scored = 255
Achievement = (Run_Scored / Target_Runs) * 100
print ("Achievement=", Achievement, "%")
# Out:
# Achievement= 85.0 %

# %% [markdown]
#  3)% use karke check karo ki 2026 ko 4 se divide karne par remainder 0 aata hai ya nahi.

# %% [markdown]
# #1
# print(2026 % 4)

# %%
#1
print(2026 % 4)
# Out:
# 2

# %% [markdown]
# #2
# A = 2026
# B = 4
# print(A % B)

# %%
#2
A = 2026
B = 4
print(A % B)
# Out:
# 2

# %% [markdown]
# #3
# num = 2026
# remainder = num % 4
# print(remainder)

# %%
#3
num = 2026
remainder = num % 4
print(remainder)
# Out:
# 2

# %% [markdown]
# BODMAS Rule

# %% [markdown]
# BODMAS - Brackets, Orders, Multiplication, Division, Addition, Subtraction
#
# Brackets (Parentheses)
# Orders (Powers, Exponents, Roots)
# Multiplication & Division (left to right)
# Addition & Subtraction (left to right)
#
# Multiplication & Division are solved left-to-right, and Addition & Subtraction are also solved left-to-right

# %% [markdown]
# #1
# print(5 + 3 * 4)

# %%
#1
print(5 + 3 * 4)
# Out:
# 17

# %% [markdown]
# #2
# print((8 + 2) * 5)

# %%
#2
print((8 + 2) * 5)
# Out:
# 50

# %% [markdown]
# #3
# print(20 / 5 * 2)

# %%
#3
print(20 / 5 *2)
# Out:
# 8.0

# %% [markdown]
# #4
# print(2 + 3 * (4 ** 2 - 6))

# %%
#4
print(2+3 *(4 ** 2 - 6))
# Out:
# 32

# %% [markdown]
# #4
# y = mx + c
# m = 3
# c = 2
# x = 5
# y = m * x + c
# print(y)

# %%
#4
m = 3
c = 2
x = 5
y = m * x + c
print(y)
# Out:
# 17

# %% [markdown]
# #5
# Mobile Recharge                y = mx + c  equation of a straight line in algebra and coordinate geometry
# base_charge = 199
# cost_per_gb = 20
# extra_gb = 5
#
# total_bill = (cost_per_gb * extra_gb) + base_charge
#
# print("Base Charge: ₹", base_charge)
# print("Extra Data Used:", extra_gb, "GB")
# print("Cost per GB: ₹", cost_per_gb)
# print("Total Bill: ₹", total_bill)

# %%
#5
base_charge = 199
cost_per_gb = 20
extra_gb = 5

total_bill = (cost_per_gb * extra_gb) + base_charge

print("Base Charge: ₹", base_charge)
print("Extra Data Used:", extra_gb, "GB")
print("Cost per GB: ₹", cost_per_gb)
print("Total Bill: ₹", total_bill)
# Out:
# Base Charge: ₹ 199
# Extra Data Used: 5 GB
# Cost per GB: ₹ 20
# Total Bill: ₹ 299

# %% [markdown]
#  CLASS 13 — Strings & f-strings

# %% [markdown]
# 1)Apna name aur city store karke f-string se print karo "Hi, I am ___ from ___."

# %% [markdown]
# #1
# name = "Priya"
# city = "Jaipur"
# print(f"Hi, I am {name} from {city}.")

# %%
name = "Priya"
city = "Jaipur"
print(f"Hi, I am {name} from {city}.")
# Out:
# Hi, I am Priya from Jaipur.

# %% [markdown]
# #2
# Name = "Ansh"
# City = "Hinganghat"
# print(f"Hi, I am {Name} from {City}")

# %%
#2
Name = "Ansh"
City = "Hinganghat"
print(f"Hi, I am {Name} from {City}")
# Out:
# Hi, I am Ansh from Hinganghat

# %% [markdown]
# #3
# Shop = Electric
# City = Wardha
# State = MH
# Country = India
# print(f"Shop: {Shop}, City: {City}, State: {State}, Country: {Country}")

# %%
#3
Shop = "Electric"
City = "Wardha"
State = "MH"
Country = "India"
print(f"Shop: {Shop}, City: {City}, State: {State}, Country: {Country}")
# Out:
# Shop: Electric, City: Wardha, State: MH, Country: India

# %% [markdown]
# 2)cost = 250 aur qty = 4 store karke total f-string se print karo.

# %% [markdown]
# #1
# cost = 250
# qty = 4
# print(f"Total is {cost * qty} rupees")

# %%
#1
cost = 250
qty = 4
print(f"Total is {cost * qty} rupees")
# Out:
# Total is 1000 rupees

# %% [markdown]
# #2
# Cost = 800
# Qty = 5
# print(f"Total is {Cost * Qty} rupees")

# %%
#2
Cost = 800
Qty = 5
print(f"Total is {Cost * Qty} rupees")
# Out:
# Total is 4000, rupees

# %% [markdown]
# #3
# Cost = 1500
# Qty = 10
# print(f"Total is {Cost * Qty} rupees")

# %%
#3
Cost = 1500
Qty = 10
print(f"Total is {Cost * Qty} rupees")
# Out:
# Total is 15000 rupees

# %% [markdown]
# 3)marks = 367 store karo, 450 mein se percentage 2 decimals ke saath print karo.

# %% [markdown]
# # .2Show 2 digits after the decimal point, f  Display the number as a floatingpoint decimal value

# %%
#1 .2 Show 2 digits after the decimal point, f  Display the number as a floating-point decimal value
marks = 367
print(f"Percentage: {marks / 450 * 100:.2f}%")
# Out:
# Percentage: 81.56%

# %% [markdown]
# #2
# marks = 425
# total = 500
# percentage = (marks / total) * 100
# print(f"Percentage: {percentage:.2f}%")

# %%
#2
marks = 425
total = 500
percentage = (marks / total) * 100
print(f"Percentage: {percentage:.2f}%")
# Out:
# Percentage: 85.00%

# %% [markdown]
# #3
# marks = 367
# total = 450
# percentage = (marks / total) * 100
# print(f"Percentage: {percentage:.2f}%")

# %%
#3
marks = 367
total = 450
percentage = (marks / total) * 100
print(f"Percentage: {percentage:.2f}%")
# Out:
# Percentage: 81.56%

# %% [markdown]
# CLASS 14 — Booleans, Types & Type Conversion

# %% [markdown]
# or operator checks whether at least one condition is True, not operator reverses the Boolean value, and operator checks whether both conditions are True.

# %% [markdown]
# 1)Do boolean variables banao aur unpar and, or, not ka result print karo.

# %% [markdown]
# #1
# is_Ansh_passed = True
# is_Golu_passed = False
# print(iis_Ansh_passed and is_Golu_passed)
# print(is_Ansh_passed or is_Golu_passed)
# print(not is_Golu_passed)

# %%
#1
is_Ansh_passed = True
is_Golu_passed = False
print(is_Ansh_passed and is_Golu_passed)   
print(is_Ansh_passed or is_Golu_passed)   
print(not is_Golu_passed)
# Out:
# False
# True
# True

# %% [markdown]
# #2
# fingerprint_match = True
# face_match = True
# print(fingerprint_match and face_match)
# print(fingerprint_match or face_match)
# print(not face_match)

# %%
#2
fingerprint_match = True
face_match = True
print(fingerprint_match and face_match)
print(fingerprint_match or face_match)
print(not face_match)
# Out:
# True
# True
# False

# %% [markdown]
# #3
# math_pass = True
# science_pass = False
# print(math_pass and science_pass)

# %%
#3
math_pass = True
science_pass = False
print(math_pass and science_pass)
# Out:
# False

# %% [markdown]
# 2)String "45" ko number mein convert karke 5 add karo.

# %% [markdown]
# #1
# num = int("45")
# print(num + 5)

# %%
#1
num = int("45")
print(num + 5)
# Out:
# 50

# %% [markdown]
# #2
# marks = int("80")
# print(marks + 20)

# %%
#2
marks = int("80")
print(marks + 20)
# Out:
# 100

# %% [markdown]
# #3
# x = int("150")
# print(x - 50)

# %%
#3
x = int("150")
print(x - 50)
# Out:
# 100

# %% [markdown]
# 3)Predict phir check karo: 10 == 10.0 → True ya False? int(7.8) → ?

# %% [markdown]
# #1
# print(10 == 10.0)
# print(int(7.8))

# %%
#1
print(10 == 10.0)                
print(int(7.8))
# Out:
# True
# 7

# %% [markdown]
# #2
# print(5 == 5.0)

# %%
#2
print(5 == 5.0)
# Out:
# True

# %% [markdown]
# #3
# print(5 == 6.0)

# %%
#3
print(5 == 6.0)
# Out:
# False

# %% [markdown]
# CLASS 15 — Input/Output, String Methods & Mini Project

# %% [markdown]
# 1)Ek program banao jo name aur birth year poochhe, phir age print kare.

# %% [markdown]
# #1
# name = input("Name: ")
# birth_year = int(input("Birth year: "))
# print(f"{name}, you are about {2026 - birth_year} years old")

# %%
#1
name = input("Name: ")
birth_year = int(input("Birth year: "))
print(f"{name}, you are about {2026 - birth_year} years old")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 #1
#       2 name = input("Name: ")
# ----> 3 birth_year = int(input("Birth year: "))
#       4 print(f"{name}, you are about {2026 - birth_year} years old")
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# 2)Ek simple bill calculator: item price aur quantity poochho, total ₹ aur 2 decimals ke saath print karo.

# %% [markdown]
# #2
# price = float(input("Price: "))
# qty = int(input("Quantity: "))
# print(f"Total: ₹{price * qty:.2f}")

# %%
#2
price = float(input("Price: "))
qty = int(input("Quantity: "))
print(f"Total: ₹{price * qty:.2f}")

# %% [markdown]
# 3)User se ek messy sentence maango, phir use stripped aur uppercase mein print karo.

# %% [markdown]
# #3
# msg = input("Type a sentence: ")
# print(msg.strip().upper())

# %%
#3
msg = input("Type a sentence: ")
print(msg.strip().upper())
