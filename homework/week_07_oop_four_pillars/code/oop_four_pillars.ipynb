# %% [markdown]
# # Week 7 - OOP: The four Pillars

# %% [markdown]
# Object-Oriented Programming (OOP) is a programming approach where we organize data and the functions that work with that data into objects.

# %% [markdown]
# # CLASS 41 — Classes & Objects

# %% [markdown]
# CONCEPT 1 — Class & Objects
#
# A class is a blueprint or template used to create objects. It defines the attributes (data) and methods (behaviour) that objects created from the class can have.
#
#
# An object is a specific instance of a class. It contains its own data and can use the methods defined by its class.

# %%
class Dog:
    def __init__(self, name, age, colour):
        self.name = name
        self.age = age
        self.colour = colour

    def bark(self):
        print(f"{self.name} says woof!")

# %%
dog1 = Dog("Tommy", 5, "white")

# %%
dog1.name
# Out:
# 'Tommy'

# %%
dog1.colour
# Out:
# 'white'

# %%
dog1.bark()
# Out:
# Tommy says woof!

# %%
dog2 = Dog("Tipu", 20, "black")

# %%
dog2.bark()
# Out:
# Tipu says woof!

# %%
dog2.age
# Out:
# 20

# %% [markdown]
# Concept 2 — __init__
#
#
# __init__: A special method that Python automatically calls when a new object is created. It is used to initialize the object's attributes.

# %%
class Student:
    def __init__(self, name, age, marks):
        self.name = name
        self.age = age
        self.marks = marks

# %%
khushi_obj = Student("Kushi", 20, 79)

# %%
khushi_obj.marks
# Out:
# 79

# %% [markdown]
# Concept 3 — self
#
# self: The conventional name for the first parameter of an instance method. It refers to the current object.

# %%
class Student:
    def __init__(wow, name, age, marks):
        wow.name = name
        wow.age = age
        wow.marks = marks

# %%
st_1 = Student("khushi", 20, 79)
st_1.name
# Out:
# 'khushi'

# %%
class Counter:
    def __init__(self):
        self.count = 0

    def increase(self):
        self.count += 1

# %%
counter = Counter()

# %%
counter.increase()

# %%
counter.count
# Out:
# 1

# %%
counter.increase()

# %%
counter.count
# Out:
# 2

# %% [markdown]
# Concept 4 — attributes vs methods
#
# An attribute is a piece of data or state that belongs to an object. Attributes represent the characteristics or properties of an object.
#
# A method is a function defined inside a class that describes the behaviour or actions an object can perform.

# %% [markdown]
# | Term           | Proper Meaning                         | Easy Meaning   |
# | -------------- | -------------------------------------- | -------------- |
# | **Class**      | Blueprint for creating objects         | Naksha         |
# | **Object**     | Instance of a class                    | Actual thing   |
# | **`__init__`** | Initializes an object's starting state | Starting setup |
# | **`self`**     | Refers to the current object           | Ye wala object |
# | **Attribute**  | Data/state belonging to an object      | What it HAS    |
# | **Method**     | Function representing object behaviour | What it DOES   |

# %% [markdown]
# # CLASS 42 — Encapsulation

# %% [markdown]
# CONCEPT 1 — What is Encapsulation?
#
# Encapsulation is an OOP principle that combines data and the methods that work with that data inside a class, while controlling how the data can be accessed or changed from outside the class.

# %%
class BankAccount:
    def __init__(self, balance):
        self.balance = balance

# %%
bank_account_1 = BankAccount(1000)

# %%
bank_account_2 = BankAccount(5000)

# %%
bank_account_1.balance
# Out:
# 1000

# %%
bank_account_2.balance
# Out:
# 5000

# %%
bank_account_1.balance = -500

# %%
bank_account_1.balance
# Out:
# -500

# %% [markdown]
# CONCEPT 2 — Single Underscore _

# %%
class BankAccount:
    def __init__(self, balance):
        self._balance = balance

    def deposit(self, amount):
        if amount > 0:
            self._balance += amount

    def withdraw(self, amount):
        if amount > 0:
            self._balance -= amount
        return print("Available balance is", self._balance) 

    def get_balance(self):
        return self._balance

# %%
bank_account_1 = BankAccount(3000)

# %%
bank_account_1._balance
# Out:
# 3000

# %%
bank_account_1.withdraw(500)
# Out:
# Available balance is 2500

# %% [markdown]
# CONCEPT 3 — Validation
#
# Validation is the process of checking whether input data follows the required rules before accepting or using it.
#
#
# Validation = Check the input before accepting it.

# %%
class BankAccount:
    """
    A class to represent a bank account.
    Attributes:
    balance (int): The balance of the bank account.
    Methods:
        deposit(amount: int) -> None: Deposit money into the account.
        withdrw(ammout: int) -> None: withdraw money from the account.
        get_balance() -> int: Get the current balance of the account.
    """
    
    def __init__(self, balance: int):
        self._balance = balance

    def deposit(self, amount: int) -> None:
        if amount <= 0:
            return print("Invalid amount")


        if amount > 0:
            self._balance += amount
        return print("Available balance is", self._balance)    

    def withdraw(self, amount: int) -> None:
        if amount <= 0:
            return print("Invalid amount")
            
        if amount > 0:
            self._balance -= amount
        return print("Available balance is", self._balance) 

    def get_balance(self) -> int:
        return self._balance

# %%
bank_account_1 = BankAccount(3000)

# %%
bank_account_1.deposit(-500)
# Out:
# Invalid amount

# %% [markdown]
# CONCEPT 4 — Double Underscore __
#
# A double leading underscore (__) triggers name mangling, which changes the internal attribute name to reduce accidental access and name conflicts from outside the class.
#
#
# __ makes direct access to the attribute harder.

# %%
class BankAccount:
    """
    A class to represent a bank account.
    Attributes:
    balance (int): The balance of the bank account.
    Methods:
        deposit(amount: int) -> None: Deposit money into the account.
        withdrw(ammout: int) -> None: withdraw money from the account.
        get_balance() -> int: Get the current balance of the account.
    """
    
    def __init__(self, balance: int):
        self.__balance = balance

    def deposit(self, amount: int) -> None:
        if amount <= 0:
            return print("Invalid amount")


        if amount > 0:
            self.__balance += amount
        return print("Available balance is", self.__balance)    

    def withdraw(self, amount: int) -> None:
        if amount <= 0:
            return print("Invalid amount")

        if amount > self.__balance:
            return print("Insufficient balance")

        if amount > 0:
            self.__balance -= amount
        return print("Available balance is", self.__balance) 

    def get_balance(self) -> int:
        return self.__balance

# %%
bank_account_1 = BankAccount(300)

# %%
bank_account_1._balance
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 bank_account_1._balance
#
# AttributeError: 'BankAccount' object has no attribute '_balance'

# %%
bank_account_1.get_balance()
# Out:
# 300

# %%
bank_account_1.withdraw(500)
# Out:
# Insufficient balance

# %%
bank_account_1.withdraw(300)
# Out:
# Available balance is 0

# %% [markdown]
# Industry Interview Questions — Week 7
# Real interview-style questions covering this week's topics, with model answers (in English). Try to answer them yourself first, then read the solution.
#
# Q1. What is the difference between a class and an object, and what are __init__ and self?
#
# A class is a blueprint that defines attributes and behavior; an object (instance) is a concrete thing built from that blueprint. __init__ is the initializer that runs when you create an instance and sets up its starting attributes. self is the reference to the specific instance, passed automatically as the first parameter of every instance method, so the method can read and modify that object's own data.
#
# Q2. Name the four pillars of OOP and explain each in one line.
#
# Encapsulation — bundling data with the methods that operate on it and hiding internal details. Inheritance — a child class reusing and extending a parent class. Polymorphism — the same method name behaving correctly on different types (one interface, many implementations). Abstraction — exposing a simple, essential interface while hiding complex implementation, often via abstract base classes.
#
# Q3. How does Python implement encapsulation, given it has no truly "private" members?
#
# By convention and name mangling rather than hard access control. A single underscore (_value) signals "internal, please don't touch" but is not enforced. A double underscore (__value) triggers name mangling — Python renames it to _ClassName__value, which discourages accidental access and avoids clashes in subclasses. Real validation/encapsulation is achieved with properties (getters/setters) rather than blocking access outright.
#
# Q4. Inheritance vs composition — which should you prefer and why?
#
# Prefer composition ("has-a": an object holds other objects) over inheritance ("is-a": a subclass extends a parent) in most cases. Deep inheritance hierarchies are rigid and create tight coupling, whereas composition is flexible and easier to change and test. Use inheritance only when there is a genuine "is-a" relationship and you want to share/override behavior. This is the classic guideline: "favor composition over inheritance."
#
# Q5. What is an abstract base class (ABC) and why use one?
#
# An ABC (from the abc module, with @abstractmethod) defines a contract: it cannot be instantiated directly, and any concrete subclass must implement the abstract methods or Python raises a TypeError. This guarantees a consistent interface across implementations — for example an abstract Tool with a run() method ensures every tool your agent uses is callable the same way, so you can treat them polymorphically in a loop.
