# %% [markdown]
# # Week 6 - Functions: Clean, Typed & Modular

# %% [markdown]
# Class 36 - Scope & Closures

# %% [markdown]
# Concept 1 - Local Scope

# %% [markdown]
# Local Scope is the area inside a function where variables are created and used. A variable created inside a function exists only while that function is running and cannot be accessed from outside the function.
#
# In other words, local variables belong only to the function in which they are created.

# %%
def my_function():
    x = 10
    print(x)

# %%
my_function()
# Out:
# 10

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %% [markdown]
# Concept 2 - Global Scope
#
# A Global Scope is the area outside all functions where variables are created. A variable defined in the global scope is called a global variable. It can be accessed from anywhere in the program, including inside functions (for reading), as long as it is not shadowed by a local variable.

# %%
greet = "Hello"

def greeting():
    print(greet)

# %%
greeting()
# Out:
# Hello

# %%
print(greet)
# Out:
# Hello

# %%
def update_greet():
    user_name = "Sham"
    greet = greet +" "+ user_name
    print(greet)

# %%
update_greet()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 update_greet()
#
# Cell In[9], line 3, in update_greet()
#       1 def update_greet():
#       2     user_name = "Sham"
# ----> 3     greet = greet +" "+ user_name
#       4     print(greet)
#
# UnboundLocalError: cannot access local variable 'greet' where it is not associated with a value

# %% [markdown]
# Concept 3 - Global Keyword
#
# The global keyword is used inside a function to tell Python that a variable refers to the global variable (the one created outside the function). It allows the function to modify the global variable instead of creating a new local variable.
#
# Without global, assigning a value inside a function creates a local variable.

# %%
greet
# Out:
# 'Hello'

# %%
def update_greet():
    global greet
    user_name = "Sham"
    greet = greet +" "+ user_name
    print(greet)

# %%
update_greet()
# Out:
# Hello Sham

# %%
greet
# Out:
# 'Hello Sham'

# %%
user_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 user_name
#
# NameError: name 'user_name' is not defined

# %% [markdown]
# Concept 3 - Closure
#
# A closure is a function that remembers the variables from its outer (enclosing) function even after the outer function has finished executing.
#
# In other words, the inner function keeps access to the outer function's local variables, even though those variables would normally disappear after the outer function ends.

# %%
def f():
    def f():
        def f():
            def f():
                def f():
                    def f():
                        def f():
                            def f():
                                pass

# %%
def make_multi(n):
    print("N : ", n)
    def multi(x):
        print("X : ", x)
        return x*n

    return multi

# %%
double = make_multi(5)
# Out:
# N :  5

# %%
double(3)
# Out:
# X :  3
# 15

# %% [markdown]
# ## Class 37 - Recursion
#
#
# Concept 1 – What is Recursion?
#
# Recursion is a programming technique in which a function calls itself to solve a problem by breaking it into smaller versions of the same problem.
#
# Every recursive function must have:
#
# Base Case – the stopping condition.
# Recursive Case – where the function calls itself.
#
# Without a base case, recursion never stops.

# %%
def countdown(n):
    print(n)
    if n == 1:
        print("Countdown finished")
        return
        
    countdown(n-1)

# %%
countdown(5)
# Out:
# 5
# 4
# 3
# 2
# 1
# Countdown finished

# %% [markdown]
# Concept 2 – Factorial Using Recursion

# %% [markdown]
# A factorial is the product of a positive integer and all the positive integers smaller than it.
#
# It is represented by the ! (factorial) symbol.
#
# For example:
# 5! = 5 × 4 × 3 × 2 × 1 = 120
#
# Using recursion, a factorial is calculated by multiplying the current number by the factorial of the previous number until the base case is reached.

# %% [markdown]
# factorial(5)
#
# ↓
#
# 5 × factorial(4)
#
# ↓
#
# 5 × 4 × factorial(3)
#
# ↓
#
# 5 × 4 × 3 × factorial(2)
#
# ↓
#
# 5 × 4 × 3 × 2 × factorial(1)
#
# ↓
#
# Base Case
#
# ↓
#
# return 1
#
# ↓
#
# 2 × 1 = 2
#
# ↓
#
# 3 × 2 = 6
#
# ↓
#
# 4 × 6 = 24
#
# ↓
#
# 5 × 24 = 120

# %%
def factorial(n):
    if n == 1:
        return 1
    return n * factorial(n - 1)

# %%
factorial(2)
# Out:
# 2

# %%
factorial(5)
# Out:
# 120

# %%
factorial(8)
# Out:
# 40320

# %% [markdown]
# Concept 3 – Recursion with Nested Data

# %%
def sum_nest_list(list_data):
    total = 0

    for item in list_data:
        if isinstance(item, list):
            total = total + sum_nest_list(item)
        else:
            total = total + item
    return total

# %%
sum_nest_list([1, 2, [3, 4, [5, 6]], 7])
# Out:
# 28

# %% [markdown]
# Concept 4 – When Should You NOT Use Recursion?
#
# Recursion is not always the best solution. If a problem can be solved more simply, efficiently, or clearly using a loop (for or while), then recursion should generally be avoided.
#
# Recursive functions create additional function calls, which consume more memory and can be slower than iterative solutions.

# %% [markdown]
# # CLASS 38 — Docstrings & Type Hints

# %% [markdown]
# Concept 1 - Type Hints
#
# Type Hints are optional annotations that specify the expected data types of function parameters and return values. They improve code readability and help developers and tools understand how a function should be used.
#
# Type hints do not enforce types at runtime.

# %%
def add(a: int, b: int) -> int:
    return a + b

# %%
add(1, 3)
# Out:
# 4

# %%
def greet(name: str) -> str:
    return "Hello, " + name

# %%
greet("Ansh")
# Out:
# 'Hello, Ansh'

# %% [markdown]
# Concept 2 – Docstrings
#
#
# A Docstring (Documentation String) is a special string written as the first statement inside a function, class, or module. It describes what the code does, what parameters it expects, and what it returns.
#
# Docstrings are enclosed in triple quotes (""" """ or ''' ''').

# %%
def greet(name):
    """
    Returns a greeting message for the given name.
    """
    return f"Hello, {name}!"

# %%
print(greet("Ansh"))
# Out:
# Hello, Ansh!

# %% [markdown]
# Concept 3 – Using Docstrings and Type Hints Together
#
# Professional Python functions often combine type hints and docstrings to clearly describe:
#
# Expected inputs
# Return values
# Purpose of the function
#
# This makes the code easier to read, maintain, and use.

# %%
def square(number: int) -> int:
    """
    Returns the square of a number.
    """
    return number ** 2

# %%
print(square(5))
# Out:
# 25

# %% [markdown]
# # CLASS 39 — lambda, map & filter

# %% [markdown]
# Concept 1 – Lambda (Mini One-Line Function)
#
# Lambda:
# A lambda is a small, anonymous function written in a single line. It accepts arguments and automatically returns the result of one expression without using the def keyword or an explicit return statement.

# %%
def squre(x: int) -> int:
    return x ** 2

# %%
squre(3)
# Out:
# 9

# %%
square_lm = lambda x: x ** 2

# %%
square_lm(5)
# Out:
# 25

# %%
check_neg_pos_num = lambda num: "negative" if num  < 0 else "positive"

# %%
check_neg_pos_num(-4)
# Out:
# 'negative'

# %%
check_neg_pos_num(7)
# Out:
# 'positive'

# %%
add_fun = lambda a,b: a + b

# %%
add_fun(4, 5)
# Out:
# 9

# %% [markdown]
# Concept 2 – map()
#
# map():
# The map() function applies a given function to every item in an iterable (such as a list) and returns a lazy iterator containing the transformed values. Use list() to see the results.

# %%
nums = [3,4,5,1,2]

list(map(lambda x: x ** 2, nums))
# Out:
# [9, 16, 25, 1, 4]

# %%
nums = [-3,4,-5,1,-2]

# %%
get_tf_of_num = lambda num: False if num < 0 else True

# %%
get_tf_of_num(-5)
# Out:
# False

# %%
get_tf_of_num(8)
# Out:
# True

# %%
tf_nums = list(map(get_tf_of_num, nums))

# %%
tf_nums
# Out:
# [False, True, False, True, False]

# %% [markdown]
# Concept 3 – filter()
#
# filter():
# The filter() function keeps only the items for which the given function returns True. It returns a lazy iterator, so wrap it in list() to view the filtered results.

# %%
nums = [-3,4,-5,1,-2]

# %%
list(filter(get_tf_of_num, nums))
# Out:
# [4, 1]

# %%
tuple(filter(get_tf_of_num, nums))
# Out:
# (4, 1)

# %%
set(filter(get_tf_of_num, nums))
# Out:
# {1, 4}

# %%
dict(filter(get_tf_of_num, nums))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 dict(filter(get_tf_of_num, nums))
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %% [markdown]
# Concept 4 – Passing Functions as Arguments
#
# Functions as Arguments:
# In Python, functions are first-class objects. This means a function can be stored in a variable, passed as an argument to another function, and returned from another function.

# %%
def apply(function, value):
    return function(value)

print(apply(lambda x: x * 10, 5))
# Out:
# 50

# %% [markdown]
# # Class 40 - Modules & pip (Project Class)

# %% [markdown]
# Concept 1 – Module & Import
#
# Module:
# A module is a single Python (.py) file that contains reusable code, such as functions, classes, and variables.
#
# Import:
# The import statement loads a module into another Python file so you can use its code without rewriting it.

# %%
import math

sqrt = math.sqrt(16)
tan_value = math.tan(45)

import random

from datetime import datetime

# %%
sqrt
# Out:
# 4.0

# %%
tan_value
# Out:
# 1.6197751905438615

# %%
random.randint(1, 100)
# Out:
# 50

# %%
datetime.now()
# Out:
# datetime.datetime(2026, 8, 4, 20, 8, 6, 137557)

# %% [markdown]
# Concept 2 – Creating Your Own Module
#
# Any Python file (.py) can act as a module. Functions defined in one file can be imported and used in another file.

# %%
import tools

# %%
num1 = 3
num2 = 5

# %%
tools.add(num1, num2)
# Out:
# 8

# %%
numbers = [7,4,5,9,0,3,3,4]

# %%
from src import my_maths

my_maths.avarage(numbers)
# Out:
# 4

# %%
print(my_maths.avarage.__doc__)
# Out:
# Gives the avarage value of given list of numbers
#
# Args:
# nums (list[int]): list of numbers
#
# Returns:
#     float: avarge value of given list of numbers

# %%
from src .data import student_data

# %%
marks = student_data.marks
subject = student_data.subject

# %%
print(subject)
# Out:
# ['Maths', 'Science', 'English', 'Hindi', 'Social Studies']

# %%
my_maths.avarage(marks)
# Out:
# 89

# %%
import tools

# %%
tools.function_list
# Out:
# ['add', 'sub', 'mul', 'div', 'mods']

# %% [markdown]
# Concept 3 – if __name__ == "__main__":
#
# When a Python file is run directly, Python automatically sets the special variable __name__ to "__main__".

# %%
import tools

# %%
tools.__name__
# Out:
# 'tools'

# %%
__name__
# Out:
# '__main__'

# %%
import tools

# %% [markdown]
# Concept 4 – pip
#
# pip is Python's package installer. It downloads and installs third-party packages (and their dependencies) from the Python Package Index (PyPI), allowing you to use external libraries in your projects.

# %% [markdown]
# pip install pandas
# import pandas

# %% [markdown]
# 🎤 Industry Interview Questions — Week 6
# Real interview-style questions covering this week's topics, with model answers (in English). Try to answer them yourself first, then read the solution.
#
# Q1. Explain Python's LEGB scope rule and what the global keyword does.
#
# When you use a name, Python looks it up in this order: Local (inside the current function), Enclosing (any outer functions), Global (module level), then Built-in. The first match wins. By default, assigning to a name inside a function creates a local variable; the global keyword tells Python to bind the module-level name instead. global is generally discouraged because shared mutable global state makes code hard to reason about and test — prefer passing values in and returning them out.
#
# Q2. What is a closure, and give a real use case.
#
# A closure is an inner function that "remembers" variables from its enclosing scope even after the outer function has returned. It lets you carry state without a class. A common use is a configurable function factory — e.g. make_multiplier(n) returns a function that multiplies by n — or a counter that keeps its running total. Decorators are built on closures.
#
# Q3. Do type hints change how the program runs at runtime?
#
# No. Python does not enforce type hints at runtime — def f(x: int) will still accept a string and run. Hints are metadata used by static checkers (mypy), IDEs (autocomplete, error highlighting), documentation, and libraries like Pydantic and FastAPI that choose to read and enforce them. They matter enormously for AI tool-calling: type hints plus docstrings are exactly what gets converted into the JSON schema an LLM uses to call your function correctly.
#
# Q4. What does if __name__ == "__main__": do and why use it?
#
# When a file is run directly, Python sets its __name__ to "__main__"; when the file is imported as a module, __name__ is the module's name. Putting your script/entry code under if __name__ == "__main__": means that code runs only when the file is executed directly, not when it's imported. This lets a file act as both a reusable module and a runnable script, and keeps test/demo code from firing on import.
#
# Q5. What is the difference between lambda, map, and filter, and when should you avoid lambda?
#
# A lambda is a small anonymous one-expression function, often passed as an argument (e.g. the key= in sorted). map(fn, iterable) applies a function to every element; filter(fn, iterable) keeps only elements for which the function is truthy. Avoid lambda when the logic is non-trivial or reused — a named def is more readable and debuggable — and in modern Python a comprehension is often clearer than map/filter with a lambda.
